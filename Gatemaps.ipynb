# %%
from qiskit import IBMQ
from qiskit.visualization import plot_gate_map, plot_error_map

IBMQ.load_account()

provider = IBMQ.get_provider(hub='ibm-q')
print(provider.backends())
# Out:
# ibmqfactory.load_account:WARNING:2022-01-25 16:22:44,251: Credentials are already in use. The existing account in the session will be replaced.
# ...

# %%
backend = provider.backends(simulator=False)[2]

print('Using backend {}'.format(backend.name())) # ibmq_santiago, etc
# Out:
# Using backend ibmq_bogota

# %%
# Plot a Gate Map for the device.
fig = plot_gate_map(backend)
# fig.savefig('gate_map.png')

# %%
# Plot an Error Map for the device.
fig = plot_error_map(backend)
# fig.savefig('error_map.png')
